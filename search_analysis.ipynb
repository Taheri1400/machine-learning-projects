# %% [markdown]
# <a href="https://colab.research.google.com/github/Taheri1400/machine-learning-projects/blob/main/search_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# تحلیل جست‌و‌جو
# </font>
# </h1>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# مقدمه و صورت مسئله
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#    در دنیای صنعت معمولاً از یک مهندس یادگیری ماشین انتظار می‌رود تا به مهارت تحلیل داده نیز آراسته باشد. جدا از این‌که ممکن است در خواسته‌های پروژه و کارفرما پرسش‌هایی مطرح شده باشد که پاسخ آن از راه تحلیل داده به دست می‌آید، تحلیل و تفسیر داده‌ها در گام‌های ابتدایی پروژه به ما کمک می‌کند تا آشنایی عمیق‌تری با داده‌هایی که در اختیارمان قرار گرفته پیدا کنیم. چنین درکی می‌تواند منجر به انتخاب راه‌حل‌ها و الگوریتم‌های مناسب‌تری در هنگام حل مسئله‌ی یادگیری ماشین شود. علاوه بر این، در صورتی‌که مجموعه‌داده‌ی ما دارای چالش‌هایی باشد می‌توانیم در همان مراحل اولیه به شناسایی و رفع آن‌ها بپردازیم.
#    <br>
#    با توجه به این موضوع، در این تمرین قصد داریم به تحلیل مجموعه‌داده‌ی جست‌و‌جوی کاربران در وب‌سایت مستربلیط بپردازیم و به چند پرسش تحلیلی، پاسخ دهیم تا به‌اصطلاح دست‌مان گرم شود. شایان ذکر است که در تمرین بعدی نیز به حل یک مسئله‌ی جالب و چالشی بر روی همین مجموعه‌داده خواهید پرداخت. 😉
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# وارد کردن کتابخانه‌های مورد نیاز
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     ابتدا کتابخانه‌های مورد نیازتان را وارد کنید.
# </font>
# </p>

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# معرفی مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     هر نمونه‌ی آموزشی از این مجموعه‌داده که در فایل <code dir=ltr>mrbilit_search.json</code> ذخیره شده مربوط به یک مرتبه جست‌و‌جوی کاربر در فیلد متنی است و با ویژگی‌هایی که در جدول زیر شرح داده شده همراه است.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |<code>ServiceType</code>|نوع سرویس|
# |<code>TypedStrings</code>|لیستی از رشته‌ی تایپ‌شده‌ی کاربر به ترتیب زمانی|
# |<code>AcceptString</code>|رشته‌ای که در نهایت انتخاب شده است|
#
# </font>
# </div>
# </center>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     همچنین لیستی از شهرهای ایران همراه با برخی اطلاعات مهم‌شان از ویکی‌پدیا جمع‌آوری شده و در فایلی با نام <code>iran_cities.csv</code> قرار گرفته است. این مجموعه‌داده‌ هرچند ناکامل است اما اکثر شهرهای مورد جست‌و‌جو را پوشش می‌دهد. ستون‌های این مجموعه‌داده در جدول زیر شرح داده شده است.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazirmatn" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |<code>City EN</code>|نام انگلیسی شهر|
# |<code>City FA</code>|نام فارسی شهر |
# |<code>Province</code>|استان|
# |<code>Countise</code>|شهرستان|
# |<code>District</code>|بخش|
# |<code>Latitude</code>|عرض جغرافیایی|
# |<code>Longitude</code>|طول جغرافیایی|
# |<code>Area</code>|مساحت (کیلومتر مربع)|
# |<code>Elevation</code>|ارتفاع (متر)|
# |<code>2016 Census</code>|جمعیت سال ۲۰۱۶|
# |<code>2011 Census</code>|جمعیت سال ۲۰۱۱|
# |<code>Wikipedia EN</code>|لینک ویکی‌پدیا انگلیسی|
# |<code>Wikipedia FA</code>|لینک ویکی‌پدیا فارسی|
# |<code>GeoHack</code>|لینک سایت GeoHack|
#
# </font>
# </div>
# </center>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# خواندن مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     در ابتدا می‌توانید فایل‌های مجموعه‌داده‌ها را بخوانید. لازم به ذکر است برای خواندن فایل‌های <code>json</code> به شکل یک دیتافریم <code>pandas</code> می‌توانید از تابع <code dir=ltr>read_json()</code> استفاده کنید.
# </font>
# </p>

# %%
data = pd.read_json('mrbilit_search.json')
data.head()
# Out:
#   ServiceType                                       TypedStrings  \
# 0      flight                                     [, ف, فل, فلو]
# 1       hotel  [, H, H,, H, , آ, آو, آوا, آواپ, آواپل, آواپلا...
# 2       hotel       [, آ, آو, آوا, آواپ, آواپل, آواپلا, آواپلاس]
# 3       hotel                                                 []
# 4         bus                                                 []
#
#                    AcceptString
# 0                       فلورانس
# 1                         شیراز
# 2                       آواپلاس
# 3  بین المللی اسپیناس خلیج فارس
# 4                         تهران

# %%
cities = pd.read_csv('iran_cities.csv')
cities.head()
# Out:
#      City EN City FA Province Countise District   Latitude  Longitude  \
# 0     Ab Bar   آب‌بر    زنجان     طارم    مرکزی  36.918100  48.964700
# 1  Ab Pakhsh  آب‌پخش    بوشهر  دشتستان   آب‌پخش  29.363706  51.070180
# 2       Abad    آباد    بوشهر  تنگستان    مرکزی  29.028300  51.249100
# 3     Abadan  آبادان  خوزستان   آبادان    مرکزی  30.339167  48.304167
# 4     Abadeh   آباده     فارس    آباده    مرکزی  31.180000  52.670000
#
#        Area  Elevation  2016 Census  2011 Census  \
# 0     709.0        NaN       8091.0       6725.0
# 1  251204.0     7003.0      18913.0      17238.0
# 2      45.0        NaN       3787.0       3787.0
# 3       3.0        NaN     231476.0     212744.0
# 4    1890.0        NaN      59116.0      55758.0
#
#                                   Wikipedia EN  \
# 0         https://en.wikipedia.org/wiki/Ab_Bar
# 1      https://en.wikipedia.org/wiki/Ab_Pakhsh
# 2  https://en.wikipedia.org/wiki/Abad,_Bushehr
# 3   https://en.wikipedia.org/wiki/Abadan,_Iran
# 4         https://en.wikipedia.org/wiki/Abadeh
#
#                                         Wikipedia FA  \
# 0  https://fa.wikipedia.org/wiki/%D8%A2%D8%A8%E2%...
# 1  https://fa.wikipedia.org/wiki/%D8%A2%D8%A8%E2%...
# 2  https://fa.wikipedia.org/wiki/%D8%A2%D8%A8%D8%...
# 3  https://fa.wikipedia.org/wiki/%D8%A2%D8%A8%D8%...
# 4  https://fa.wikipedia.org/wiki/%D8%A2%D8%A8%D8%...
#
#                                              GeoHack
# 0  https://geohack.toolforge.org/geohack.php?lang...
# 1  https://geohack.toolforge.org/geohack.php?lang...
# 2  https://geohack.toolforge.org/geohack.php?lang...
# 3  https://geohack.toolforge.org/geohack.php?lang...
# 4  https://geohack.toolforge.org/geohack.php?lang...

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# محبوبیت سرویس‌ها
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
# در ابتدا قصد داریم درصد محبوبیت هرکدام از سرویس‌ها (اتوبوس، هواپیما، تاکسی و غیره) را بررسی کنیم. برای این کار نیاز است به ازای هر سرویس (ستون <code>ServiceType</code>) محاسبه کنید که چند درصد از کل جست‌و‌جوها را شامل می‌شود. پاسخ خود را به شکل یک دیکشنری و همچون فرمت زیر در متغیر <code>percentages</code> ذخیره کنید. سپس به کمک کدی که برای‌تان آماده شده می‌توانید نمودار دایره‌ای (Pie Chart) آن را رسم کنید.
# </font>
# </p>

# %%
import pandas as pd
import plotly.express as px

data = pd.read_json('mrbilit_search.json')

# محاسبه نسبت هر سرویس (فراوانی نسبی)
service_ratios = data['ServiceType'].value_counts(normalize=True)

# اطمینان از داشتن کلیدهای موردنظر با مقدار صفر اگر وجود نداشتند
percentages = {
    service: float(service_ratios.get(service, 0))
    for service in ['bus', 'flight', 'train', 'hotel', 'taxi', 'ship']
}

print(percentages)

# رسم نمودار دایره‌ای (مقادیر بین 0 و 1 هم رسم می‌شوند)
fig = px.pie(
    values=percentages.values(),
    names=list(percentages.keys()),
    title='Pie Chart of Service Types'
)
fig.show()
# Out:
# {'bus': 0.40237178034594756, 'flight': 0.24959589092831785, 'train': 0.17912229020318754, 'hotel': 0.10012840849006722, 'taxi': 0.05196767127426543, 'ship': 0.016813958758214367}
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="04c173b2-a8b2-49dd-b0a8-8e2a631eb1c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04c173b2-a8b2-49dd-b0a8-8e2a631eb1c1")) {                    Plotly.newPlot(                        "04c173b2-a8b2-49dd-b0a8-8e2a631eb1c1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["bus","flight","train","hotel","taxi","ship"],"legendgroup":"","name":"","showlegend":true,"values":[0.40237178034594756,0.24959589092831785,0.17912229020318754,0.10012840849006722,0.05196767127426543,0.016813958758214367],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewid ...

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# پیش‌پردازش
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
# برای حل قسمت‌های بعدی نیاز به شمارش جست‌و‌جوها براساس شهر خواهیم داشت. با این حال، اگر مقادیر ستون <code>AcceptString</code> را مشاهده کنید، متوجه خواهید شد که برخی از مقادیر به شکلی مثل «شیراز - پایانه امیرکبیر» نوشته شده‌اند. برای این‌که چنین مقادیری نیز تنها به اسم شهر تبدیل شوند نیاز است در این ستون دنبال تمام مقادیری که شامل عبارت « - » هستند بگردید و آن‌ها را با بخش اول مقدار یعنی نام شهر جایگزین کنید. به‌عنوان مثال به‌جای «شیراز - پایانه امیرکبیر» باید مقدار «شیراز» قرار گیرد. دیتافریم حاصل را در متغیری به نام <code>preprocessed_data</code> ذخیره کنید.
# </font>
# </p>

# %%
import pandas as pd

# 1. کپی داده‌ها
preprocessed_data = data.copy()

# 2. حذف پسوندها در AcceptString (مثلاً "شیراز - پایانه امیرکبیر" => "شیراز")
preprocessed_data['AcceptString'] = preprocessed_data['AcceptString'].str.split(' - ').str[0]

# 3. حذف مقادیر خالی در AcceptString (اگر وجود دارد)
preprocessed_data = preprocessed_data[preprocessed_data['AcceptString'].notna()]

# 4. نرمال‌سازی نام شهرها (حذف فاصله اضافی، تبدیل به حروف کوچک برای تطبیق بهتر)
preprocessed_data['AcceptString'] = preprocessed_data['AcceptString'].str.strip()

# 5. بارگذاری داده شهرها (اگر قبلاً بارگذاری نشده)
cities = pd.read_csv('iran_cities.csv')

# نرمال‌سازی نام شهرها در cities هم (برای تطبیق بهتر)
cities['City FA'] = cities['City FA'].str.strip()

# 6. ادغام داده‌ها براساس نام شهر فارسی
merged_data = preprocessed_data.merge(cities, left_on='AcceptString', right_on='City FA', how='left')

# نمایش ۵ ردیف اول داده ادغام شده
merged_data.head()
# Out:
#   ServiceType                                       TypedStrings  \
# 0      flight                                     [, ف, فل, فلو]
# 1       hotel  [, H, H,, H, , آ, آو, آوا, آواپ, آواپل, آواپلا...
# 2       hotel       [, آ, آو, آوا, آواپ, آواپل, آواپلا, آواپلاس]
# 3       hotel                                                 []
# 4         bus                                                 []
#
#                    AcceptString City EN City FA Province Countise District  \
# 0                       فلورانس     NaN     NaN      NaN      NaN      NaN
# 1                         شیراز  Shiraz   شیراز     فارس    شیراز    مرکزی
# 2                       آواپلاس     NaN     NaN      NaN      NaN      NaN
# 3  بین المللی اسپیناس خلیج فارس     NaN     NaN      NaN      NaN      NaN
# 4                         تهران  Tehran   تهران    تهران    تهران    مرکزی
#
#    Latitude  Longitude        Area  Elevation  2016 Census  2011 Census  \
# 0       NaN        NaN         NaN        NaN          NaN          NaN
# 1       NaN        NaN         NaN        NaN    1565572.0    1460665.0
# 2       NaN        NaN         NaN        NaN          NaN          NaN
# 3       NaN        NaN         NaN        NaN          NaN          NaN
# 4      35.7       51.4  90018004.0     7513.0    8693706.0    8154051.0
#
#                            Wikipedia EN  \
# 0                                   NaN
# 1  https://en.wikipedia.org/wiki/Shiraz
# 2                                   NaN
# 3                                   NaN
# 4  https://en.wikipedia.org/wiki/Tehran
#
#                                         Wikipedia FA  \
# 0                                                NaN
# 1  https://fa.wikipedia.org/wiki/%D8%B4%DB%8C%D8%...
# 2                                                NaN
# 3                                                NaN
# 4  https://fa.wikipedia.org/wiki/%D8%AA%D9%87%D8%...
#
#                                              GeoHack
# 0                                                NaN
# 1  https://geohack.toolforge.org/geohack.php?lang...
# 2                                                NaN
# 3                                                NaN
# 4  https://geohack.toolforge.org/geohack.php?lang...

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3 color=green>
# <b>نکته:</b>
# </font>
# <font face="vazirmatn" size=3>
# قسمت‌های بعدی را با دیتافریم <code>preprocessed_data</code> ادامه دهید. توجه داشته باشید که مقادیر موجود در این دیتافریم را تغییری ندهید.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# بیشترین جست‌و‌جوها
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
# در این قسمت ابتدا تنها سطرهایی را که سرویس‌شان از نوع هتل نیست در دیتافریم دیگری به نام <code>data_transport</code> ذخیره کنید.
# حال در این دیتافریم کدام شهرها (ستون <code>AcceptString</code>) بیشترین جست‌و‌جو را داشته‌اند؟ نام <b>۲۰</b> مورد محبوب‌تر را به‌ترتیب در لیستی به نام <code>top_cities</code> ذخیره کنید. در نهایت به کمک کدی که برای‌تان آماده کرده‌ایم نمودار هیستوگرام این شهرها رسم خواهد شد.
# </font>
# </p>

# %%
import plotly.express as px

# 1. فیلتر کردن سطرهایی که سرویس‌شان هتل نیست
data_transport = preprocessed_data[preprocessed_data['ServiceType'] != 'hotel']

# 2. شمارش تعداد جست‌وجوها بر اساس AcceptString
city_counts = data_transport['AcceptString'].value_counts()

# 3. استخراج ۲۰ شهر پرجست‌وجو
top_cities = city_counts.head(20).index.tolist()

# 4. فیلتر کردن داده‌ها فقط برای این ۲۰ شهر
temp = data_transport[data_transport['AcceptString'].isin(top_cities)]

# 5. رسم نمودار هیستوگرام
fig = px.histogram(temp, x="AcceptString", title='Histogram of Top 20 Cities')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c964c881-22ac-4085-a4e0-4234c87a5a01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c964c881-22ac-4085-a4e0-4234c87a5a01")) {                    Plotly.newPlot(                        "c964c881-22ac-4085-a4e0-4234c87a5a01",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"AcceptString=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["تهران","تهران","اصفهان","اصفهان","اصفهان","تهران","تهران","مشهد","تهران","تهران","مشهد","اصفهان","اراک","تهران","تهران","کرج","تهران","قم","قم","تهران","اصفهان","تهران","مشهد","اهواز","اصفهان","مشهد","یزد","مشهد","اصفهان","تهران","مشهد","اهواز","قم","مشهد","مشهد","تهران","مشهد","مشهد","مشهد","مشهد","شیراز","اصفهان","تهران","مشهد","تبریز","مشهد","مشهد","مشهد","مشهد","اهواز","مشهد","تهران","اصفهان","تهران","تهران","شیراز","اصفهان","اصفهان","شیراز","تهران","شیراز","تهران","بندرعباس","بندرعباس","تهران","تهران","تهران","مشهد","بندرعباس","بندرعباس","تهران","مشهد","تهران","اصفهان","تهران","تهران","اهواز","تهران","رشت","مشهد","تبریز","مشهد","تهران","کرج","آبادان","اصفهان","رشت","تبریز","تهران","اصفهان","اهواز","اصفهان","قم","تبریز","تهران","رشت","اصفهان","قم","اصفهان","آبادان","اصفهان","اهواز","تهران","بندرعباس","رشت","شیراز","آبادان","شیراز","شیراز","کیش","اراک","مشهد","یزد","کرج","شیراز","تهران","تهران","قم","تهران","یزد","اصفهان","قم","مشهد","تهران","ساری","قم","تهران","اصفهان","اهواز","تهران","تهران","گرگان","مشهد","اهواز","تهران","زاهدان","زاهدان","مشهد","تهران","قم","تهران","کیش","کرج","تهران","مشهد","کرمان","اصفهان","بندرعباس","یزد","کیش","کرمان","تهران","کیش","اهواز","مشهد","تهران","اهواز","اهواز","اهواز","تهران","تهران","تهران","اراک","اهواز","اصفهان","اصفهان","تهران","یزد","تهران","تهران","تهران","تهران","تهران","بندرعباس","رشت","گرگان","قم","تبریز","کرج","اهواز","اراک","رشت","رشت","اراک","تهران","اصفهان","شیراز","شیراز","تهران","تهران","اراک","رشت","رشت","تهران","تهران","مشهد","کیش","تهران","یزد","کرج","تهران","مشهد","یزد","رشت","اصفهان","یزد","اهواز","بندرعباس","بندرعباس","اراک","تهران","یزد","تهران","تبریز","تهران","یزد","بندرعباس","کرمانشاه","کیش","تهران","یزد","قم","تهران","زاهدان","یزد","بندرعباس","مشهد","اهواز","تهران","زنجان","تهران","مشهد","تهران","تهران","آبادان","مشهد","کرج","زنجان","تهران","قم","قم","بندرعباس","مشهد","تهران","تبریز","تهران","مشهد","اراک","بندرعباس","قم","تهران","تهران","اصفهان","مشهد","یزد","مشهد","مشهد","یزد","تهران","قم","تهران","اصفهان","قم","مشهد","تهران","یزد","بندرعباس","تهران","تهران","ساری","تهران","تهران","تهران","تهران","تبریز","تهران","کیش","تهران","مشهد","تهران","شیراز","مشهد","تهران","مشهد","تهران","اصفهان","مشهد","تهران","تهران","تهران","تهران","رشت","تهران","مشهد","تهران","آبادان","تهران","زاهدان","اهواز","تهران","بندرعباس","رشت","قم","تهران","کرج","کرمان","تهران","قم","بندرعباس","مشهد","اصفهان","تهران","تهران","تهران","تهران","اصفهان","قم","تبریز","تهران","یزد","مشهد","مشهد","تهران","مشهد","تهران","تهران","یزد","تهران","مشهد","تهران","قم","قم","قم","تهران","قم","تهران","تهران","گرگان","تهران","تهران","تهران","شیراز","گرگان","مشهد","تهران","تهران","تهران","قم","قم","قم","تهران","اصفهان","مشهد","مشهد","شیراز","مشهد","تهران","مشهد","تهران","گرگان","قم","تهران","اهواز","یزد","تهران","تهران","اصفهان","شیراز","تبریز","تهران","زنجان","قم","تهران","تهران","کرمانشاه","تهران","اهواز","تهران","مشهد","مشهد","کرمانشاه","کرمانشاه","مشهد","بندرعباس","مشهد","تهران","تهران","تهران","تهران","کیش","اهواز","بندرعباس","آبادان","تهران","اهواز","تهران","مشهد","اصفهان","یزد","تهران","شیراز","مشهد","رشت","تهران","تهران","قم","اصفهان","مشهد","مشهد","اهواز","تهران","تهران","شیراز" ...

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# پرجست‌و‌جوترین استان‌ها
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
# در این قسمت استان‌ها را از نظر مجموع جست‌و‌جوی شهرهای‌شان مرتب کرده و نام <b>۱۵ مورد برتر</b> را در لیستی به نام <code>top_provinces</code> ذخیره کنید. برای این کار باز هم سرویس هتل را در نظر نگیرید (از دیتافریم مرحله‌ی قبل یعنی <code>data_transport</code> استفاده کنید). توجه کنید که برای پیدا کردن نام استان هرکدام از شهرهای مورد جست‌و‌جو می‌توانید از مجموعه‌داده‌ی شهرهای ایران (فایل <code>iran_cities.csv</code>) استفاده کنید. تنها آن سطرهایی را در نظر بگیرید که مقدار ستون <code>AcceptString</code> دیتافریم اصلی در ستون <code>City FA</code> دیتافریم شهرها وجود داشته باشد. به‌عبارت دیگر اگر یک عبارت مورد جست‌و‌جو در نام فارسی مجموعه‌داده‌ی شهرها وجود نداشت از آن صرف‌نظر کنید. در صورت علاقه می‌توانید مثل بخش قبل هیستوگرام آن را نیز رسم کنید.
# </font>
# </p>

# %%
# 1. بارگذاری دیتاست شهرها (اگر قبلاً بارگذاری نشده باشه)
cities = pd.read_csv('iran_cities.csv')

# 2. نرمال‌سازی نام‌ها برای تطبیق بهتر
data_transport['AcceptString'] = data_transport['AcceptString'].str.strip()
cities['City FA'] = cities['City FA'].str.strip()

# 3. ادغام براساس اینکه AcceptString با City FA برابر باشه
merged_transport = data_transport.merge(cities[['City FA', 'Province']], left_on='AcceptString', right_on='City FA', how='inner')

# 4. شمارش تعداد جست‌وجوها برای هر استان
province_counts = merged_transport['Province'].value_counts()

# 5. استخراج ۱۵ استان برتر
top_provinces = province_counts.head(15).index.tolist()

# 6. (اختیاری) رسم هیستوگرام
import plotly.express as px

temp = merged_transport[merged_transport['Province'].isin(top_provinces)]
fig = px.histogram(temp, x='Province', title='Histogram of Top 15 Provinces')
fig.show()
# Out:
# /tmp/ipython-input-7-2132880590.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6fb91119-944d-40f0-a6cb-129050ea5d77" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6fb91119-944d-40f0-a6cb-129050ea5d77")) {                    Plotly.newPlot(                        "6fb91119-944d-40f0-a6cb-129050ea5d77",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Province=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":["تهران","تهران","تهران","تهران","خراسان رضوی","تهران","تهران","خراسان رضوی","تهران","تهران","البرز","تهران","قم","قم","تهران","تهران","خراسان رضوی","خوزستان","خراسان رضوی","یزد","خراسان رضوی","تهران","خراسان رضوی","خوزستان","قم","خراسان رضوی","خراسان رضوی","تهران","خراسان رضوی","خراسان رضوی","خراسان رضوی","خراسان رضوی","فارس","تهران","خراسان رضوی","آذربایجان شرقی","خراسان رضوی","خراسان رضوی","خراسان رضوی","خراسان رضوی","خوزستان","خراسان رضوی","تهران","تهران","تهران","فارس","فارس","تهران","فارس","تهران","هرمزگان","هرمزگان","هرمزگان","تهران","تهران","تهران","خراسان رضوی","هرمزگان","هرمزگان","هرمزگان","هرمزگان","هرمزگان","تهران","خراسان رضوی","تهران","هرمزگان","هرمزگان","سمنان","تهران","تهران","خوزستان","هرمزگان","تهران","گیلان","بوشهر","سمنان","خراسان رضوی","آذربایجان شرقی","خراسان رضوی","تهران","البرز","سمنان","خوزستان","گیلان","آذربایجان شرقی","سیستان و بلوچستان","سمنان","تهران","خوزستان","آذربایجان شرقی","مازندران","سمنان","قم","آذربایجان شرقی","تهران","گیلان","قم","خوزستان","خوزستان","تهران","هرمزگان","گیلان","فارس","خوزستان","فارس","فارس","مازندران","هرمزگان","خراسان رضوی","یزد","البرز","هرمزگان","فارس","تهران","تهران","قم","تهران","بوشهر","کرمان","یزد","قم","خراسان رضوی","تهران","مازندران","قم","تهران","خوزستان","تهران","تهران","خراسان رضوی","خوزستان","تهران","سیستان و بلوچستان","سیستان و بلوچستان","خراسان رضوی","تهران","قم","تهران","هرمزگان","البرز","تهران","خراسان رضوی","کرمان","بوشهر","هرمزگان","یزد","هرمزگان","کرمان","هرمزگان","تهران","هرمزگان","خوزستان","خراسان رضوی","تهران","خوزستان","خوزستان","خوزستان","تهران","تهران","تهران","خوزستان","تهران","یزد","تهران","تهران","تهران","تهران","تهران","هرمزگان","گیلان","قم","آذربایجان شرقی","کرمان","البرز","خوزستان","گیلان","گیلان","تهران","فارس","فارس","تهران","تهران","گیلان","گیلان","تهران","تهران","خراسان رضوی","هرمزگان","تهران","یزد","البرز","تهران","خراسان رضوی","یزد","گیلان","مازندران","یزد","خوزستان","هرمزگان","هرمزگان","تهران","یزد","تهران","آذربایجان شرقی","تهران","یزد","هرمزگان","هرمزگان","تهران","یزد","قم","تهران","سیستان و بلوچستان","یزد","هرمزگان","خراسان رضوی","خوزستان","تهران","تهران","خراسان رضوی","هرمزگان","مازندران","تهران","مازندران","تهران","خوزستان","خراسان رضوی","البرز","تهران","قم","قم","هرمزگان","خراسان رضوی","تهران","آذربایجان شرقی","تهران","خراسان رضوی","هرمزگان","هرمزگان","قم","تهران","تهران","خراسان رضوی","یزد","خراسان رضوی","بوشهر","خراسان رضوی","یزد","تهران","قم","تهران","قم","خراسان رضوی","تهران","یزد","هرمزگان","تهران","تهران","مازندران","تهران","تهران","تهران","تهران","آذربایجان شرقی","تهران","هرمزگان","تهران","خراسان رضوی","تهران","فارس","خراسان رضوی","تهران","خراسان رضوی","تهران","خراسان رضوی","تهران","تهران","تهران","تهران","گیلان","تهران","خراسان رضوی","تهران","خوزستان","سیستان و بلوچستان","تهران","سیستان و بلوچستان","خوزستان","خوزستان","تهران","هرمزگان","گیلان","قم","تهران","البرز","کرمان","خوزستان","تهران","مازندران","قم","هرمزگان","خراسان رضوی","تهران","بوشهر","هرمزگان","تهران","تهران","تهران","قم","آذربایجان شرقی","تهران","یزد","خراسان رضوی","خراسان رضوی","تهران","خراسان رضوی","تهران","فارس","تهران","یزد","تهران","خراسان رضوی","تهران","قم","قم","قم","تهران","قم","تهران","تهران","تهران","تهران","تهران","فارس","خراسان  ...

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# تحلیل جمعیت
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
# در ادامه‌ی پرسش قبل؛
# از بین شهرهایی که طبق سرشماری سال ۲۰۱۶ (ستون <code dir=ltr>2016 Census</code>) جمعیت بالای <b>۵۰۰ هزار نفر</b> داشته‌اند، کدام شهرها جزو ۲۰ شهر پر جست‌و‌جو (متغیر <code>top_cities</code>) نیستند؟ حاصل را به شکل یک لیست در متغیری به نام <code>not_in_top</code> ذخیره کنید (ترتیب اهمیتی ندارد).
# </font>
# </p>

# %%
# 1. انتخاب شهرهای با جمعیت بالای ۵۰۰ هزار نفر
high_pop_cities = cities[cities['2016 Census'] > 500_000]

# 2. گرفتن نام فارسی شهرها
high_pop_city_names = high_pop_cities['City FA'].dropna().str.strip().tolist()

# 3. پیدا کردن شهرهایی که در top_cities نیستند
not_in_top = [city for city in high_pop_city_names if city not in top_cities]

# 4. نمایش نتیجه
print("شهرهای پرجمعیت که جزو 20 شهر پرجست‌وجو نیستند:")
print(not_in_top)
# Out:
# شهرهای پرجمعیت که جزو 20 شهر پرجست‌وجو نیستند:
# ['اردبیل', 'همدان', 'ارومیه']

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazirmatn" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazirmatn" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zipfile
import joblib
import json
import os

if not os.path.exists(os.path.join(os.getcwd(), 'search_analysis.ipynb')):
    # %notebook -e text_categorization.ipynb


def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

json.dump(percentages, open('percentages.json', 'w'))
preprocessed_data.to_csv('preprocessed_data.csv', index=False)
data_transport.to_csv('data_transport.csv', index=False)
json.dump(top_cities, open('top_cities.json', 'w'))
json.dump(top_provinces, open('top_provinces.json', 'w'))
json.dump(not_in_top, open('not_in_top.json', 'w'))

file_names = ['search_analysis.ipynb', 'percentages.json', 'preprocessed_data.csv',
              'data_transport.csv', 'top_cities.json', 'top_provinces.json', 'not_in_top.json']
compress(file_names)
# Out:
# File Paths:
# ['search_analysis.ipynb', 'percentages.json', 'preprocessed_data.csv', 'data_transport.csv', 'top_cities.json', 'top_provinces.json', 'not_in_top.json']
